# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/Administratör/Desktop/ML Dataset/cs-training.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
#         age  NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 149995   74                                     0     0.225131         2100.0
# 149996   44                                     0     0.716562         5584.0
# 149997   58                                     0  3870.000000            NaN
# 149998   30                                     0     0.000000         5716.0
# 149999   64                                     0     0.249908         8158.0
#
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
data.shape
# Out:
# (150000, 12)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'SeriousDlqin2yrs',
#        'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Unnamed: 0                              150000
# SeriousDlqin2yrs                             2
# RevolvingUtilizationOfUnsecuredLines    125728
# age                                         86
# NumberOfTime30-59DaysPastDueNotWorse        16
# DebtRatio                               114194
# MonthlyIncome                            13594
# NumberOfOpenCreditLinesAndLoans             58
# NumberOfTimes90DaysLate                     19
# NumberRealEstateLoansOrLines                28
# NumberOfTime60-89DaysPastDueNotWorse        13
# NumberOfDependents                          13
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %%
data = data.dropna(subset=['MonthlyIncome','NumberOfDependents'])

# %%
data.isnull().sum()
# Out:
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
total_len = len(data['SeriousDlqin2yrs'])
percentage_labels = (data['SeriousDlqin2yrs'].value_counts()/total_len)*100
percentage_labels
# Out:
# SeriousDlqin2yrs
# 0    93.05141
# 1     6.94859
# Name: count, dtype: float64

# %%
sns.set(style="whitegrid")
total_len = len(data)
plt.figure(figsize=(6, 4))
ax = sns.countplot(x=data['SeriousDlqin2yrs'], palette="viridis")
ax.set_title('Data Distribution of SeriousDlqin2yrs', fontsize=14)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, 
            height + 2, 
            f'{100 * height / total_len:.2f}%', 
            fontsize=12, ha='center')

ax.set_xlabel("SeriousDlqin2yrs Labels", fontsize=12)
ax.set_ylabel("Number of Records", fontsize=12)

sns.set(font_scale=1.2)
plt.show()

# %%
feature_x = "NumberOfDependents"
feature_y = "MonthlyIncome"

plt.figure(figsize=(8,5))
sns.scatterplot(x=data[feature_x], y=data[feature_y], color="blue", alpha=0.5)

plt.xlabel(feature_x)
plt.ylabel(feature_y)
plt.title(f"Scatter Plot of {feature_x} vs {feature_y}")

plt.show()

# %%
corr_matrix = data.corr()

plt.figure(figsize=(8, 4))

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
data = data.drop(['NumberOfTime60-89DaysPastDueNotWorse'],axis=1)

# %%
feature =  'NumberOfDependents'  # Change this to your actual column name

# Create the boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x=data[feature])
plt.title(f"Boxplot of {feature} (Detecting Outliers)")
plt.show()

# %%
q1= data[ 'NumberOfDependents'].quantile(0.25)
q3= data[ 'NumberOfDependents'].quantile(0.75)
iqr=q3-q1

# %%
q1,q3,iqr
# Out:
# (0.0, 2.0, 2.0)

# %%
upper_limit= q3+(1.5*iqr)
lower_limit= q1-(1.5*iqr)
lower_limit,upper_limit
# Out:
# (-3.0, 5.0)

# %%
data.loc[(data['NumberOfDependents']>upper_limit)|(data['NumberOfDependents']<lower_limit)]
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 447                    0                              0.243674   48
# 1342                   0                              0.047198   74
# 2024                   1                              1.000000   46
# 2178                   0                              0.078959   39
# 2522                   0                              0.353358   40
# ...                  ...                                   ...  ...
# 148787                 0                              0.134774   45
# 149261                 0                              0.254330   58
# 149585                 0                              0.104181   49
# 149733                 0                              0.462224   57
# 149968                 1                              0.983825   55
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 447                                        0   0.179980         8900.0
# ...

# %%
new_data= data.loc[(data['NumberOfDependents']<upper_limit)&(data['NumberOfDependents']>lower_limit)]
print('before removing outliers:', len(data))
print('after removing outliers:', len(new_data))
print('outliers:', len(data)-len(new_data))
# Out:
# before removing outliers: 120269
# after removing outliers: 119348
# outliers: 921

# %%
plt.figure(figsize=(7, 4))
sns.boxplot(new_data['NumberOfDependents'])
plt.title(f"Boxplot of {feature} (Without Outliers)")
plt.show()
